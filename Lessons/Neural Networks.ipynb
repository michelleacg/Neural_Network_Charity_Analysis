# %%
# Import our dependencies
import pandas as pd
import matplotlib as plt
from sklearn.datasets import make_blobs
import sklearn as skl
import tensorflow as tf
import warnings
warnings.filterwarnings('ignore')
# Out:
# 2023-01-19 22:07:44.813321: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Generate dummy dataset
X, y = make_blobs(n_samples=1000, centers=2, n_features=2, random_state=78)

# Creating a DataFrame with the dummy data
df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df["Target"] = y

# Plotting the dummy data
df.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")
# Out:
# <AxesSubplot: xlabel='Feature 1', ylabel='Feature 2'>

# %%
# Use sklearn to split dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create scaler instance
X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()
# Out:
# 2023-01-19 22:07:53.764400: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Add our first Dense layer, including the input layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="relu", input_dim=2))

# %%
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Check the structure of the Sequential model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 3
#
#  dense_1 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model to the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 2ms/step - loss: 0.7666 - accuracy: 0.3027
# Epoch 2/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7513 - accuracy: 0.3360
# Epoch 3/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7381 - accuracy: 0.3760
# Epoch 4/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7272 - accuracy: 0.4093
# Epoch 5/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7181 - accuracy: 0.4387
# Epoch 6/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7099 - accuracy: 0.4533
# Epoch 7/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7023 - accuracy: 0.4880
# Epoch 8/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6951 - accuracy: 0.5160
# Epoch 9/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6883 - accuracy: 0.5440
# Epoch 10/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6820 - accuracy: 0.5667
# Epoch 11/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6759 - accuracy: 0.5800
# Epoch 12/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6697 - accuracy: 0.6000
# Epoch 13/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6635 - accuracy: 0.6187
# Epoch 14/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6567 - accuracy: 0.6373
# Epoch 15/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6498 - accuracy: 0.6533
# Epoch 16/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6425 - accuracy: 0.6720
# Epoch 17/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6349 - accuracy: 0.6840
# Epoch 18/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6269 - accuracy: 0.6960
# Epoch 19/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6186 - accuracy: 0.7080
# Epoch 20/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6096 - accuracy: 0.7213
# Epoch 21/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6003 - accuracy: 0.7347
# Epoch 22/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5904 - accuracy: 0.7480
# Epoch 23/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5800 - accuracy: 0.7600
# Epoch 24/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5696 - accuracy: 0.7733
# Epoch 25/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5585 - accuracy: 0.7920
# Epoch 26/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5473 - accuracy: 0.8013
# Epoch 27/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5362 - accuracy: 0.8107
# Epoch 28/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5251 - accuracy: 0.8200
# Epoch 29/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5137 - accuracy: 0.8307
# Epoch 30/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5025 - accuracy: 0.8440
# Epoch 31/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4911 - accuracy: 0.8493
# Epoch 32/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4801 - accuracy: 0.8520
# Epoch 33/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4695 - accuracy: 0.8573
# Epoch 34/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4589 - accuracy: 0.8653
# Epoch 35/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4482 - accuracy: 0.8720
# Epoch 36/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4380 - accuracy: 0.8760
# Epoch 37/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4279 - accuracy: 0.8827
# Epoch 38/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4179 - accuracy: 0.8867
# Epoch 39/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4081 - accuracy: 0.8907
# Epoch 40/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3987 - accuracy: 0.8973
# Epoch 41/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3895 - accuracy: 0.9000
# Epoch 42/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3806 - accuracy: 0.9040
# Epoch 43/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3719 - accuracy: 0.9080
# Epoch 44/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3634 - accuracy: 0.9107
# Epoch 45/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3552 - accuracy: 0.9160
# Epoch 46/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3470 - accuracy: 0.9240
# Epoch 47/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3391 - accuracy: 0.9253
# Epoch 48/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3313 - accuracy: 0.9360
# Epoch 49/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3236 - accuracy: 0.9373
# Epoch 50/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3160 - accuracy: 0.9400
# Epoch 51/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3086 - accuracy: 0.9413
# Epoch 52/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3012 - accuracy: 0.9453
# Epoch 53/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2941 - accuracy: 0.9467
# Epoch 54/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2869 - accuracy: 0.9480
# Epoch 55/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2799 - accuracy: 0.9493
# Epoch 56/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2730 - accuracy: 0.9520
# Epoch 57/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2663 - accuracy: 0.9533
# Epoch 58/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2599 - accuracy: 0.9547
# Epoch 59/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2536 - accuracy: 0.9547
# Epoch 60/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2475 - accuracy: 0.9560
# Epoch 61/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2415 - accuracy: 0.9587
# Epoch 62/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2356 - accuracy: 0.9600
# Epoch 63/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2300 - accuracy: 0.9640
# Epoch 64/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2246 - accuracy: 0.9653
# Epoch 65/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2194 - accuracy: 0.9680
# Epoch 66/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2143 - accuracy: 0.9680
# Epoch 67/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2094 - accuracy: 0.9693
# Epoch 68/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2045 - accuracy: 0.9720
# Epoch 69/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1999 - accuracy: 0.9733
# Epoch 70/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1953 - accuracy: 0.9787
# Epoch 71/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1907 - accuracy: 0.9787
# Epoch 72/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1863 - accuracy: 0.9813
# Epoch 73/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1820 - accuracy: 0.9813
# Epoch 74/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1779 - accuracy: 0.9813
# Epoch 75/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1738 - accuracy: 0.9813
# Epoch 76/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1699 - accuracy: 0.9813
# Epoch 77/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1659 - accuracy: 0.9840
# Epoch 78/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1621 - accuracy: 0.9853
# Epoch 79/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1583 - accuracy: 0.9853
# Epoch 80/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1547 - accuracy: 0.9853
# Epoch 81/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1512 - accuracy: 0.9867
# Epoch 82/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1478 - accuracy: 0.9867
# Epoch 83/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1444 - accuracy: 0.9880
# Epoch 84/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1412 - accuracy: 0.9880
# Epoch 85/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1380 - accuracy: 0.9880
# Epoch 86/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1350 - accuracy: 0.9880
# Epoch 87/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1320 - accuracy: 0.9880
# Epoch 88/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1292 - accuracy: 0.9893
# Epoch 89/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1264 - accuracy: 0.9907
# Epoch 90/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1237 - accuracy: 0.9920
# Epoch 91/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1211 - accuracy: 0.9920
# Epoch 92/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1185 - accuracy: 0.9920
# Epoch 93/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1161 - accuracy: 0.9920
# Epoch 94/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1136 - accuracy: 0.9920
# Epoch 95/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1113 - accuracy: 0.9920
# Epoch 96/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1090 - accuracy: 0.9920
# Epoch 97/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1069 - accuracy: 0.9920
# Epoch 98/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1047 - accuracy: 0.9947
# Epoch 99/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1026 - accuracy: 0.9960
# Epoch 100/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1006 - accuracy: 0.9960

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history, index=range(1,len(fit_model.history["loss"])+1))

# Plot the loss
history_df.plot(y="loss")
# Out:
# <AxesSubplot: >

# %%
# Plot the accuracy
history_df.plot(y="accuracy")
# Out:
# <AxesSubplot: >

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.0924 - accuracy: 1.0000 - 156ms/epoch - 19ms/step
# Loss: 0.09238910675048828, Accuracy: 1.0

# %%
# Predict the classification of a new set of blob data
new_X, new_Y = make_blobs(n_samples=10, centers=2, n_features=2, random_state=78)
new_X_scaled = X_scaler.transform(new_X)
(nn_model.predict(new_X_scaled) > 0.5).astype("int32")
# Out:
# 1/1 [==============================] - 0s 79ms/step
# array([[0],
#        [1],
#        [0],
#        [1],
#        [0],
#        [0],
#        [1],
#        [1],
#        [1],
#        [0]], dtype=int32)

# %%
from sklearn.datasets import make_moons

# Creating dummy nonlinear data
X_moons, y_moons = make_moons(n_samples=1000, noise=0.08, random_state=78)

# Transforming y_moons to a vertical vector
y_moons = y_moons.reshape(-1, 1)

# Creating a DataFrame to plot the nonlinear dummy data
df_moons = pd.DataFrame(X_moons, columns=["Feature 1", "Feature 2"])
df_moons["Target"] = y_moons

# Plot the nonlinear dummy data
df_moons.plot.scatter(x="Feature 1",y="Feature 2", c="Target",colormap="winter")
# Out:
# <AxesSubplot: xlabel='Feature 1', ylabel='Feature 2'>

# %%
# Create training and testing sets
X_moon_train, X_moon_test, y_moon_train, y_moon_test = train_test_split(
    X_moons, y_moons, random_state=78
)

# Create the scaler instance
X_moon_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_moon_scaler.fit(X_moon_train)

# Scale the data
X_moon_train_scaled = X_moon_scaler.transform(X_moon_train)
X_moon_test_scaled = X_moon_scaler.transform(X_moon_test)

# %%
# Training the model with the nonlinear data
model_moon = nn_model.fit(X_moon_train_scaled, y_moon_train, epochs=100, shuffle=True)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 2ms/step - loss: 1.4030 - accuracy: 0.3507
# Epoch 2/100
# 24/24 [==============================] - 0s 3ms/step - loss: 1.1996 - accuracy: 0.3760
# Epoch 3/100
# 24/24 [==============================] - 0s 2ms/step - loss: 1.0702 - accuracy: 0.4040
# Epoch 4/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.9829 - accuracy: 0.4240
# Epoch 5/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9213 - accuracy: 0.4480
# Epoch 6/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8747 - accuracy: 0.4667
# Epoch 7/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8372 - accuracy: 0.4907
# Epoch 8/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8060 - accuracy: 0.5187
# Epoch 9/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7787 - accuracy: 0.5413
# Epoch 10/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7550 - accuracy: 0.5573
# Epoch 11/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7341 - accuracy: 0.5680
# Epoch 12/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7143 - accuracy: 0.5800
# Epoch 13/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6960 - accuracy: 0.5920
# Epoch 14/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6800 - accuracy: 0.6093
# Epoch 15/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6650 - accuracy: 0.6187
# Epoch 16/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6512 - accuracy: 0.6267
# Epoch 17/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6382 - accuracy: 0.6360
# Epoch 18/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6263 - accuracy: 0.6467
# Epoch 19/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6148 - accuracy: 0.6547
# Epoch 20/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6039 - accuracy: 0.6613
# Epoch 21/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5935 - accuracy: 0.6680
# Epoch 22/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5835 - accuracy: 0.6760
# Epoch 23/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5743 - accuracy: 0.6773
# Epoch 24/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5657 - accuracy: 0.6787
# Epoch 25/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5576 - accuracy: 0.6827
# Epoch 26/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5498 - accuracy: 0.6880
# Epoch 27/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5425 - accuracy: 0.6947
# Epoch 28/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5355 - accuracy: 0.6987
# Epoch 29/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5289 - accuracy: 0.7027
# Epoch 30/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5226 - accuracy: 0.7120
# Epoch 31/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5162 - accuracy: 0.7173
# Epoch 32/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5104 - accuracy: 0.7240
# Epoch 33/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5047 - accuracy: 0.7293
# Epoch 34/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4991 - accuracy: 0.7293
# Epoch 35/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4933 - accuracy: 0.7347
# Epoch 36/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4878 - accuracy: 0.7347
# Epoch 37/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4823 - accuracy: 0.7387
# Epoch 38/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4772 - accuracy: 0.7427
# Epoch 39/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4721 - accuracy: 0.7453
# Epoch 40/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4669 - accuracy: 0.7547
# Epoch 41/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4618 - accuracy: 0.7573
# Epoch 42/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4566 - accuracy: 0.7613
# Epoch 43/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4517 - accuracy: 0.7627
# Epoch 44/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4469 - accuracy: 0.7680
# Epoch 45/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4420 - accuracy: 0.7707
# Epoch 46/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4372 - accuracy: 0.7800
# Epoch 47/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4325 - accuracy: 0.7813
# Epoch 48/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4276 - accuracy: 0.7827
# Epoch 49/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4226 - accuracy: 0.7840
# Epoch 50/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4176 - accuracy: 0.7893
# Epoch 51/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4129 - accuracy: 0.7907
# Epoch 52/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4082 - accuracy: 0.7973
# Epoch 53/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4034 - accuracy: 0.8053
# Epoch 54/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3988 - accuracy: 0.8107
# Epoch 55/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3941 - accuracy: 0.8120
# Epoch 56/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3895 - accuracy: 0.8160
# Epoch 57/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3851 - accuracy: 0.8160
# Epoch 58/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3808 - accuracy: 0.8187
# Epoch 59/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3766 - accuracy: 0.8213
# Epoch 60/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3724 - accuracy: 0.8227
# Epoch 61/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3683 - accuracy: 0.8240
# Epoch 62/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3641 - accuracy: 0.8267
# Epoch 63/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3601 - accuracy: 0.8267
# Epoch 64/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3560 - accuracy: 0.8267
# Epoch 65/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3522 - accuracy: 0.8307
# Epoch 66/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3485 - accuracy: 0.8307
# Epoch 67/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3449 - accuracy: 0.8347
# Epoch 68/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3412 - accuracy: 0.8373
# Epoch 69/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3376 - accuracy: 0.8400
# Epoch 70/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3343 - accuracy: 0.8427
# Epoch 71/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3309 - accuracy: 0.8453
# Epoch 72/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3276 - accuracy: 0.8507
# Epoch 73/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3244 - accuracy: 0.8520
# Epoch 74/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3214 - accuracy: 0.8560
# Epoch 75/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3185 - accuracy: 0.8560
# Epoch 76/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3158 - accuracy: 0.8600
# Epoch 77/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3131 - accuracy: 0.8640
# Epoch 78/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3106 - accuracy: 0.8680
# Epoch 79/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3084 - accuracy: 0.8720
# Epoch 80/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3062 - accuracy: 0.8733
# Epoch 81/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3043 - accuracy: 0.8773
# Epoch 82/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3026 - accuracy: 0.8787
# Epoch 83/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3009 - accuracy: 0.8813
# Epoch 84/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2994 - accuracy: 0.8813
# Epoch 85/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2979 - accuracy: 0.8827
# Epoch 86/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2965 - accuracy: 0.8853
# Epoch 87/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2952 - accuracy: 0.8867
# Epoch 88/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2940 - accuracy: 0.8867
# Epoch 89/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2928 - accuracy: 0.8867
# Epoch 90/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2917 - accuracy: 0.8880
# Epoch 91/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2907 - accuracy: 0.8893
# Epoch 92/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2896 - accuracy: 0.8907
# Epoch 93/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2888 - accuracy: 0.8907
# Epoch 94/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2878 - accuracy: 0.8920
# Epoch 95/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2869 - accuracy: 0.8920
# Epoch 96/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2861 - accuracy: 0.8933
# Epoch 97/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2853 - accuracy: 0.8933
# Epoch 98/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2844 - accuracy: 0.8933
# Epoch 99/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2837 - accuracy: 0.8933
# Epoch 100/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2830 - accuracy: 0.8933

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(model_moon.history, index=range(1,len(model_moon.history["loss"])+1))

# Plot the loss
history_df.plot(y="loss")
# Out:
# <AxesSubplot: >

# %%
# Plot the accuracy
history_df.plot(y="accuracy")
# Out:
# <AxesSubplot: >

# %%
# Generate our new Sequential model
new_model = tf.keras.models.Sequential()

# %%
# Add the input and hidden layer
number_inputs = 2
number_hidden_nodes = 6

new_model.add(tf.keras.layers.Dense(units=number_hidden_nodes, activation="relu", input_dim=number_inputs))

# Add the output layer that uses a probability activation function
new_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Compile the Sequential model together and customize metrics
new_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Fit the model to the training data
new_fit_model = new_model.fit(X_moon_train_scaled, y_moon_train, epochs=100, shuffle=True)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 2ms/step - loss: 0.9816 - accuracy: 0.5120
# Epoch 2/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.9166 - accuracy: 0.4933
# Epoch 3/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8571 - accuracy: 0.4200
# Epoch 4/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8031 - accuracy: 0.4293
# Epoch 5/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7554 - accuracy: 0.4533
# Epoch 6/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7105 - accuracy: 0.5160
# Epoch 7/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6695 - accuracy: 0.6293
# Epoch 8/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6321 - accuracy: 0.8093
# Epoch 9/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5967 - accuracy: 0.8427
# Epoch 10/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5648 - accuracy: 0.8520
# Epoch 11/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5345 - accuracy: 0.8573
# Epoch 12/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5065 - accuracy: 0.8667
# Epoch 13/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4800 - accuracy: 0.8707
# Epoch 14/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4561 - accuracy: 0.8747
# Epoch 15/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4343 - accuracy: 0.8827
# Epoch 16/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4145 - accuracy: 0.8867
# Epoch 17/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3968 - accuracy: 0.8853
# Epoch 18/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3805 - accuracy: 0.8867
# Epoch 19/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3659 - accuracy: 0.8867
# Epoch 20/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3529 - accuracy: 0.8920
# Epoch 21/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3413 - accuracy: 0.8920
# Epoch 22/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3314 - accuracy: 0.8920
# Epoch 23/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3221 - accuracy: 0.8947
# Epoch 24/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3143 - accuracy: 0.8933
# Epoch 25/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3070 - accuracy: 0.8933
# Epoch 26/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3008 - accuracy: 0.8947
# Epoch 27/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2952 - accuracy: 0.8947
# Epoch 28/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2903 - accuracy: 0.8973
# Epoch 29/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2858 - accuracy: 0.8987
# Epoch 30/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2818 - accuracy: 0.8987
# Epoch 31/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2781 - accuracy: 0.9000
# Epoch 32/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2749 - accuracy: 0.8987
# Epoch 33/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2720 - accuracy: 0.8973
# Epoch 34/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2694 - accuracy: 0.8973
# Epoch 35/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2668 - accuracy: 0.8973
# Epoch 36/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2647 - accuracy: 0.8973
# Epoch 37/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2628 - accuracy: 0.8987
# Epoch 38/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2607 - accuracy: 0.8987
# Epoch 39/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2590 - accuracy: 0.8987
# Epoch 40/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2573 - accuracy: 0.8973
# Epoch 41/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2559 - accuracy: 0.8973
# Epoch 42/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2544 - accuracy: 0.8987
# Epoch 43/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2530 - accuracy: 0.8987
# Epoch 44/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2517 - accuracy: 0.9000
# Epoch 45/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2506 - accuracy: 0.9013
# Epoch 46/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2494 - accuracy: 0.9000
# Epoch 47/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2483 - accuracy: 0.9013
# Epoch 48/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2473 - accuracy: 0.9013
# Epoch 49/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2463 - accuracy: 0.9027
# Epoch 50/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2453 - accuracy: 0.9013
# Epoch 51/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2443 - accuracy: 0.9027
# Epoch 52/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2433 - accuracy: 0.9027
# Epoch 53/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2424 - accuracy: 0.9027
# Epoch 54/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2415 - accuracy: 0.9027
# Epoch 55/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2407 - accuracy: 0.9040
# Epoch 56/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2400 - accuracy: 0.9053
# Epoch 57/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2390 - accuracy: 0.9040
# Epoch 58/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2382 - accuracy: 0.9040
# Epoch 59/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2374 - accuracy: 0.9040
# Epoch 60/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2368 - accuracy: 0.9067
# Epoch 61/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2358 - accuracy: 0.9067
# Epoch 62/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2352 - accuracy: 0.9067
# Epoch 63/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2344 - accuracy: 0.9067
# Epoch 64/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2338 - accuracy: 0.9080
# Epoch 65/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2330 - accuracy: 0.9067
# Epoch 66/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2324 - accuracy: 0.9067
# Epoch 67/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2317 - accuracy: 0.9067
# Epoch 68/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2311 - accuracy: 0.9080
# Epoch 69/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2304 - accuracy: 0.9067
# Epoch 70/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2298 - accuracy: 0.9067
# Epoch 71/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2291 - accuracy: 0.9067
# Epoch 72/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2285 - accuracy: 0.9067
# Epoch 73/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2280 - accuracy: 0.9080
# Epoch 74/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2274 - accuracy: 0.9067
# Epoch 75/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2269 - accuracy: 0.9093
# Epoch 76/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2263 - accuracy: 0.9093
# Epoch 77/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2259 - accuracy: 0.9093
# Epoch 78/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2253 - accuracy: 0.9080
# Epoch 79/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2249 - accuracy: 0.9080
# Epoch 80/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2245 - accuracy: 0.9080
# Epoch 81/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2240 - accuracy: 0.9080
# Epoch 82/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2236 - accuracy: 0.9093
# Epoch 83/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2231 - accuracy: 0.9080
# Epoch 84/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2227 - accuracy: 0.9080
# Epoch 85/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2223 - accuracy: 0.9080
# Epoch 86/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2219 - accuracy: 0.9080
# Epoch 87/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2215 - accuracy: 0.9080
# Epoch 88/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2211 - accuracy: 0.9080
# Epoch 89/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2210 - accuracy: 0.9080
# Epoch 90/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2204 - accuracy: 0.9080
# Epoch 91/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2200 - accuracy: 0.9080
# Epoch 92/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2197 - accuracy: 0.9080
# Epoch 93/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2193 - accuracy: 0.9080
# Epoch 94/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2189 - accuracy: 0.9067
# Epoch 95/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2186 - accuracy: 0.9067
# Epoch 96/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2182 - accuracy: 0.9067
# Epoch 97/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2179 - accuracy: 0.9067
# Epoch 98/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2176 - accuracy: 0.9053
# Epoch 99/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2173 - accuracy: 0.9067
# Epoch 100/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2169 - accuracy: 0.9067
